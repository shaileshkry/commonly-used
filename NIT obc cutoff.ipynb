# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("nit obc 5th round cutoff.xlsx")

# %%
close_rank=60000

# %%
df.head()
# Out:
#                                            Institute  \
# 0  Dr. B R Ambedkar National Institute of Technol...
# 1  Dr. B R Ambedkar National Institute of Technol...
# 2  Dr. B R Ambedkar National Institute of Technol...
# 3  Dr. B R Ambedkar National Institute of Technol...
# 4  Dr. B R Ambedkar National Institute of Technol...
#
#                                Academic Program Name Quota Seat Type  \
# 0   Bio Technology (4 Years, Bachelor of Technology)    HS   OBC-NCL
# 1   Bio Technology (4 Years, Bachelor of Technology)    HS   OBC-NCL
# 2   Bio Technology (4 Years, Bachelor of Technology)    OS   OBC-NCL
# 3   Bio Technology (4 Years, Bachelor of Technology)    OS   OBC-NCL
# 4  Chemical Engineering (4 Years, Bachelor of Tec...    HS   OBC-NCL
#
#                                   Gender  Opening Rank  Closing Rank  \
# 0                         Gender-Neutral         52003         81089
# 1  Female-only (including Supernumerary)         41323         41323
# ...

# %%
df.columns.tolist()
# Out:
# ['Institute',
#  'Academic Program Name',
#  'Quota',
#  'Seat Type',
#  'Gender',
#  'Opening Rank',
#  'Closing Rank',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9']

# %%
# Specify the columns to drop
columns_to_drop = ['Unnamed: 7','Unnamed: 8','Unnamed: 9']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# %%
df.columns.tolist()
# Out:
# ['Institute',
#  'Academic Program Name',
#  'Quota',
#  'Seat Type',
#  'Gender',
#  'Opening Rank',
#  'Closing Rank']

# %%
len(df)
# Out:
# 1141

# %%
df['Gender'].unique()
# Out:
# array(['Gender-Neutral', 'Female-only (including Supernumerary)'],
#       dtype=object)

# %%
df['Quota'].unique()
# Out:
# array(['HS', 'OS', 'GO', 'JK'], dtype=object)

# %%
df_os=df[df['Quota']=='OS']
len(df_os)
# Out:
# 602

# %%
df_close_rank=df[df["Closing Rank"]>=close_rank]

# %%
len(df_close_rank)
# Out:
# 63

# %%
df_close_rank.head(3)
# Out:
#                                            Institute  \
# 0  Dr. B R Ambedkar National Institute of Technol...
# 4  Dr. B R Ambedkar National Institute of Technol...
# 5  Dr. B R Ambedkar National Institute of Technol...
#
#                                Academic Program Name Quota Seat Type  \
# 0   Bio Technology (4 Years, Bachelor of Technology)    HS   OBC-NCL
# 4  Chemical Engineering (4 Years, Bachelor of Tec...    HS   OBC-NCL
# 5  Chemical Engineering (4 Years, Bachelor of Tec...    HS   OBC-NCL
#
#                                   Gender  Opening Rank  Closing Rank
# 0                         Gender-Neutral         52003         81089
# 4                         Gender-Neutral         48968         64555
# 5  Female-only (including Supernumerary)         44955         62792

# %%
df_close_rank.to_excel('df_closingrank60000.xlsx')

# %%
df_close_rank.to_csv('df_closingrank60000.csv')

# %%
df_close_rank['Gender'].unique()
# Out:
# array(['Gender-Neutral', 'Female-only (including Supernumerary)'],
#       dtype=object)

# %%
df_close_rank_Gender_Neutral=df_close_rank[df_close_rank["Gender"]== "Gender-Neutral"]

# %%
len(df_close_rank_Gender_Neutral)
# Out:
# 33

# %%
df_close_rank_Gender_Neutral
# Out:
#                                               Institute  \
# 0     Dr. B R Ambedkar National Institute of Technol...
# 4     Dr. B R Ambedkar National Institute of Technol...
# 8     Dr. B R Ambedkar National Institute of Technol...
# 32    Dr. B R Ambedkar National Institute of Technol...
# 52    Dr. B R Ambedkar National Institute of Technol...
# 306                National Institute of Technology Goa
# 316                National Institute of Technology Goa
# 325                National Institute of Technology Goa
# 334           National Institute of Technology Hamirpur
# 338           National Institute of Technology Hamirpur
# 350           National Institute of Technology Hamirpur
# 362           National Institute of Technology Hamirpur
# 366           National Institute of Technology Hamirpur
# 374           National Institute of Technology Hamirpur
# 499         National Institute of Technology Puducherry
# 566             National Institute of Technology Sikkim
# ...

# %%
df_close_rank_Female=df_close_rank[df_close_rank["Gender"]== 'Female-only (including Supernumerary)']

# %%
len(df_close_rank_Female)
# Out:
# 30

# %%
df_close_rank_Female
# Out:
#                                              Institute  \
# 5    Dr. B R Ambedkar National Institute of Technol...
# 33   Dr. B R Ambedkar National Institute of Technol...
# 53   Dr. B R Ambedkar National Institute of Technol...
# 307               National Institute of Technology Goa
# 317               National Institute of Technology Goa
# 326               National Institute of Technology Goa
# 327               National Institute of Technology Goa
# 335          National Institute of Technology Hamirpur
# 339          National Institute of Technology Hamirpur
# 351          National Institute of Technology Hamirpur
# 359          National Institute of Technology Hamirpur
# 363          National Institute of Technology Hamirpur
# 367          National Institute of Technology Hamirpur
# 375          National Institute of Technology Hamirpur
# 500        National Institute of Technology Puducherry
# 507        National Institute of Technology Puducherry
# ...

# %%
df.columns.tolist()
# Out:
# ['Institute',
#  'Academic Program Name',
#  'Quota',
#  'Seat Type',
#  'Gender',
#  'Opening Rank',
#  'Closing Rank']

# %%
# Specify the columns to drop
columns_to_drop = ['Unnamed: 7','Unnamed: 8','Unnamed: 9']

# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# %%
# Plot the DataFrame as an image using matplotlib
fig, ax = plt.subplots(figsize=(8, 2))  # Adjust the size as needed
ax.axis('tight')
ax.axis('off')
table = ax.table(cellText=df_close_rank.values, colLabels=df_close_rank.columns, cellLoc='center', loc='center')
table.auto_set_font_size(False)
table.set_fontsize(10)
table.scale(1.2, 1.2)

# %%
# Save the plot as a PNG image
plt.savefig('dataframe.png', bbox_inches='tight', dpi=300)
plt.close()
